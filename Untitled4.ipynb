# %%
import pandas as pd
import os
import glob as gb
from tensorflow import keras

from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense

# %%
TRAIN_DIR = "C:\\Users\\User\\Downloads\\images\\train"
TEST_DIR = "C:\\Users\\User\\Downloads\\images\\test"
BATCH_SIZE=256

# %%
for folder in os.listdir(TRAIN_DIR):
    files = gb.glob(pathname= str(TRAIN_DIR+ '/'+ folder + '/*.jpg'))
    print(f'For training data, found {len(files)} in folder {folder}')
# Out:
# For training data, found 3993 in folder angry
# For training data, found 436 in folder disgust
# For training data, found 4103 in folder fear
# For training data, found 7164 in folder happy
# For training data, found 4982 in folder neutral
# For training data, found 4938 in folder sad
# For training data, found 3205 in folder surprise

# %%
for folder in os.listdir(TEST_DIR):
    files = gb.glob(pathname= str(TEST_DIR+ '/'+ folder + '/*.jpg'))
    print(f'For testing data, found {len(files)} in folder {folder}')
# Out:
# For testing data, found 960 in folder angry
# For testing data, found 111 in folder disgust
# For testing data, found 1018 in folder fear
# For testing data, found 1825 in folder happy
# For testing data, found 1216 in folder neutral
# For testing data, found 1139 in folder sad
# For testing data, found 797 in folder surprise

# %%
import random
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

def view_random_image(target_dir, target_class):
    # We will view images from here
    target_folder = target_dir + target_class
    
    # Get a random image path
    random_image = random.sample(os.listdir(target_folder), 1)
    
    # read in the image and plot it using matplolib
    img = mpimg.imread(target_folder+'/'+random_image[0])
    plt.imshow(img)
    plt.title(target_class)
    plt.axis('off')
    print(f"Image shape {img.shape}")
    
    return img

# %%
class_names = ['angry','disgust','fear','happy','sad','surprise']

# %%
plt.figure(figsize=(20,10))
for i in range(18):
    plt.subplot(3, 6, i+1)
    class_name = random.choice(class_names)
    img = view_random_image(target_dir="C:\\Users\\User\\Downloads\\images\\train\\", target_class=class_name)
# Out:
# Image shape (48, 48)
# Image shape (48, 48)
# Image shape (48, 48)
# Image shape (48, 48)
# Image shape (48, 48)
# Image shape (48, 48)
# Image shape (48, 48)
# Image shape (48, 48)
# Image shape (48, 48)
# Image shape (48, 48)
# Image shape (48, 48)
# Image shape (48, 48)
# Image shape (48, 48)
# Image shape (48, 48)
# Image shape (48, 48)
# Image shape (48, 48)
# Image shape (48, 48)
# Image shape (48, 48)

# %%
from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)

test_datagen = ImageDataGenerator(rescale = 1./255)

training_set = train_datagen.flow_from_directory(TRAIN_DIR,
                                                 target_size = (128, 128),
                                                 batch_size = BATCH_SIZE,
                                                 class_mode = 'categorical')

test_set = test_datagen.flow_from_directory(TEST_DIR,
                                            target_size = (128, 128),
                                            batch_size = BATCH_SIZE,
                                            class_mode = 'categorical')
# Out:
# Found 28821 images belonging to 7 classes.
# Found 7066 images belonging to 7 classes.

# %%
# Initialising the CNN
classifier = Sequential()

# Step 1 - Convolution
classifier.add(Conv2D(16, (3, 3), input_shape = (128, 128, 3), activation = 'relu'))

# Step 2 - Pooling
classifier.add(MaxPooling2D(pool_size = (2, 2)))

# Adding a second convolutional layer
classifier.add(Conv2D(32, (3, 3), activation = 'relu'))
classifier.add(MaxPooling2D(pool_size = (2, 2)))



# Step 3 - Flattening
classifier.add(Flatten())

# Step 4 - Full connection
classifier.add(Dense(units = 128, activation = 'relu'))

classifier.add(Dense(units = 7, activation = 'softmax'))

# Compiling the CNN
classifier.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])

# %%
## model summary
classifier.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 126, 126, 16)      448
#
#  max_pooling2d_4 (MaxPooling  (None, 63, 63, 16)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 61, 61, 32)        4640
#
#  max_pooling2d_5 (MaxPooling  (None, 30, 30, 32)       0
#  2D)
#
#  flatten_2 (Flatten)         (None, 28800)             0
#
#  dense_4 (Dense)             (None, 128)               3686528
#
#  dense_5 (Dense)             (None, 7)                 903
#
# =================================================================
# Total params: 3,692,519
# Trainable params: 3,692,519
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = classifier.fit(training_set,
                         epochs = 10,
                         validation_data = test_set)


classifier.save('model1.h5')  # creates a HDF5 file 'my_model.h5'
# Out:
# Epoch 1/10
# 113/113 [==============================] - 241s 2s/step - loss: 1.7927 - accuracy: 0.2941 - val_loss: 1.6247 - val_accuracy: 0.3803
# Epoch 2/10
# 113/113 [==============================] - 195s 2s/step - loss: 1.6040 - accuracy: 0.3790 - val_loss: 1.5302 - val_accuracy: 0.4188
# Epoch 3/10
# 113/113 [==============================] - 195s 2s/step - loss: 1.5424 - accuracy: 0.4088 - val_loss: 1.4908 - val_accuracy: 0.4343
# Epoch 4/10
# 113/113 [==============================] - 195s 2s/step - loss: 1.4891 - accuracy: 0.4266 - val_loss: 1.4551 - val_accuracy: 0.4380
# Epoch 5/10
# 113/113 [==============================] - 202s 2s/step - loss: 1.4541 - accuracy: 0.4414 - val_loss: 1.4465 - val_accuracy: 0.4482
# Epoch 6/10
# 113/113 [==============================] - 198s 2s/step - loss: 1.4193 - accuracy: 0.4539 - val_loss: 1.3894 - val_accuracy: 0.4666
# Epoch 7/10
# 113/113 [==============================] - 212s 2s/step - loss: 1.3920 - accuracy: 0.4654 - val_loss: 1.3905 - val_accuracy: 0.4714
# Epoch 8/10
# 113/113 [==============================] - 199s 2s/step - loss: 1.3682 - accuracy: 0.4730 - val_loss: 1.3829 - val_accuracy: 0.4656
# Epoch 9/10
# 113/113 [==============================] - 203s 2s/step - loss: 1.3542 - accuracy: 0.4805 - val_loss: 1.3501 - val_accuracy: 0.4796
# Epoch 10/10
# 113/113 [==============================] - 237s 2s/step - loss: 1.3230 - accuracy: 0.4945 - val_loss: 1.3443 - val_accuracy: 0.4837

# %%
classifier.evaluate(test_set)
# Out:
# 28/28 [==============================] - 12s 423ms/step - loss: 1.3443 - accuracy: 0.4837
# [1.344258189201355, 0.4837248921394348]

# %%
pd.DataFrame(history.history)[['loss','val_loss']].plot()
plt.title('Loss')
plt.xlabel('epochs')
plt.ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')

# %%
pd.DataFrame(history.history)[['accuracy','val_accuracy']].plot()
plt.title('Accuracy')
plt.xlabel('epochs')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
model_path = "model1.h5"
loaded_model = keras.models.load_model(model_path)

import matplotlib.pyplot as plt
import numpy as np
import cv2
from PIL import Image

image = cv2.imread("0.jpg")

image_fromarray = Image.fromarray(image, 'RGB')
resize_image = image_fromarray.resize((128, 128))
expand_input = np.expand_dims(resize_image,axis=0)
input_data = np.array(expand_input)
input_data = input_data/255

pred = loaded_model.predict(input_data)
result = pred.argmax()
result
# Out:
# 1/1 [==============================] - 0s 97ms/step
# 0

# %%
training_set.class_indices
# Out:
# {'angry': 0,
#  'disgust': 1,
#  'fear': 2,
#  'happy': 3,
#  'neutral': 4,
#  'sad': 5,
#  'surprise': 6}
